# %%
import pandas as pd
# Membaca file CSV
data = pd.read_csv('/content/sample_data/dataset-datamining.csv', delimiter=';')

# %%
print (data.isnull().sum())
print (data.shape)
# Out:
# No                    0
# Rombel Saat Ini       0
# Nama                  0
# NIPD                  1
# JK                    0
#                    ...
# Bujur                99
# No KK              1188
# Berat Badan           0
# Tinggi Badan          0
# Lingkar Kepala        0
# Length: 62, dtype: int64
# (2498, 62)

# %%
data.drop(["Rombel Saat Ini", "No", "Nama", "NIPD", "JK", "NISN",	"Tempat Lahir",	"Tanggal Lahir",	"NIK",	"Agama",	"Alamat",	"RT"	,"RW",	"Dusun"	,"Kelurahan",	"Kecamatan"	,"Kode Pos", "Telepon",	"HP",	"E-Mail"	,"SKHUN"	,	"No. KPS", "Nama Ayah", "Tahun Lahir Ayah", "Pendidikan Ayah", "NIK Ayah", "Nama Ibu", "Tahun Lahir Ibu", "Pendidikan Ibu", "NIK Ibu", "Nama Wali", "Tahun Lahir Wali", "Pendidikan Wali", "NIK Wali", "Nomor KIP", "Nama di KIP", "No Registrasi Akta Lahir", "Bank", "Nomor Rekening Bank", "Rekening Atas Nama", "Sekolah Asal", "Lintang", "Bujur", "No KK", "Berat Badan", "Tinggi Badan", "Lingkar Kepala"], inplace=True,axis=1)

# %%
print (data.isnull().sum())
print (data.shape)
# Out:
# Jenis Tinggal                         0
# Alat Transportasi                     0
# Penerima KPS                          0
# Pekerjaan Ayah                       12
# Penghasilan Ayah                     13
# Pekerjaan Ibu                         0
# Penghasilan Ibu                       0
# Pekerjaan Wali                     2196
# Penghasilan Wali                   2362
# Penerima KIP                          0
# Nomor KKS                          2425
# Layak PIP (usulan dari sekolah)       0
# Alasan Layak PIP                   1827
# Kebutuhan Khusus                      0
# Anak ke-berapa                       23
# dtype: int64
# (2498, 15)

# %%
data.drop(["Pekerjaan Wali", "Penghasilan Wali", "Anak ke-berapa", "Nomor KKS"], inplace=True,axis=1)

# %%
data.drop(["Alasan Layak PIP"], inplace=True,axis=1)

# %%
print (data.isnull().sum())
print (data.shape)
# Out:
# Jenis Tinggal                       0
# Alat Transportasi                   0
# Penerima KPS                        0
# Pekerjaan Ayah                     12
# Penghasilan Ayah                   13
# Pekerjaan Ibu                       0
# Penghasilan Ibu                     0
# Penerima KIP                        0
# Layak PIP (usulan dari sekolah)     0
# Kebutuhan Khusus                    0
# dtype: int64
# (2498, 10)

# %%
data['Pekerjaan Ayah'] = data['Pekerjaan Ayah'].fillna('Tidak Diketahui')
data['Penghasilan Ayah'] = data['Penghasilan Ayah'].fillna('Tidak Berpenghasilan')

# %%
print (data.isnull().sum())
print (data.shape)
# Out:
# Jenis Tinggal                      0
# Alat Transportasi                  0
# Penerima KPS                       0
# Pekerjaan Ayah                     0
# Penghasilan Ayah                   0
# Pekerjaan Ibu                      0
# Penghasilan Ibu                    0
# Penerima KIP                       0
# Layak PIP (usulan dari sekolah)    0
# Kebutuhan Khusus                   0
# dtype: int64
# (2498, 10)

# %%
data.head()
# Out:
#        Jenis Tinggal Alat Transportasi Penerima KPS   Pekerjaan Ayah  \
# 0  Bersama orang tua            Sepeda           Ya   Pedagang Kecil
# 1  Bersama orang tua            Sepeda        Tidak  Karyawan Swasta
# 2  Bersama orang tua      Sepeda motor        Tidak  Karyawan Swasta
# 3  Bersama orang tua      Sepeda motor        Tidak  Karyawan Swasta
# 4  Bersama orang tua      Sepeda motor        Tidak  Karyawan Swasta
#
#                 Penghasilan Ayah    Pekerjaan Ibu  \
# 0      Rp. 500,000 - Rp. 999,999    Tidak bekerja
# 1  Rp. 1,000,000 - Rp. 1,999,999  Karyawan Swasta
# 2  Rp. 2,000,000 - Rp. 4,999,999  Karyawan Swasta
# 3  Rp. 2,000,000 - Rp. 4,999,999    Tidak bekerja
# 4  Rp. 2,000,000 - Rp. 4,999,999    Tidak bekerja
#
#                  Penghasilan Ibu Penerima KIP Layak PIP (usulan dari sekolah)  \
# 0           Tidak Berpenghasilan           Ya                              Ya
# 1  Rp. 1,000,000 - Rp. 1,999,999        Tidak                           Tidak
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2498 entries, 0 to 2497
# Data columns (total 10 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Jenis Tinggal                    2498 non-null   object
#  1   Alat Transportasi                2498 non-null   object
#  2   Penerima KPS                     2498 non-null   object
#  3   Pekerjaan Ayah                   2498 non-null   object
#  4   Penghasilan Ayah                 2498 non-null   object
#  5   Pekerjaan Ibu                    2498 non-null   object
#  6   Penghasilan Ibu                  2498 non-null   object
#  7   Penerima KIP                     2498 non-null   object
#  8   Layak PIP (usulan dari sekolah)  2498 non-null   object
#  9   Kebutuhan Khusus                 2498 non-null   object
# dtypes: object(10)
# memory usage: 195.3+ KB

# %%
# Ubah tipe data kolom menjadi string
data['Penghasilan Ayah'] = data['Penghasilan Ayah'].astype(str)

# %%
# Ubah tipe data kolom menjadi string
data['Penghasilan Ibu'] = data['Penghasilan Ibu'].astype(str)

# %%
unique_penghasilan = data['Penghasilan Ayah'].unique()

# %%
print("Penghasilan yang ditemukan:", unique_penghasilan)
# Out:
# Penghasilan yang ditemukan: ['Rp. 500,000 - Rp. 999,999' 'Rp. 1,000,000 - Rp. 1,999,999'
#  'Rp. 2,000,000 - Rp. 4,999,999' 'Tidak Berpenghasilan'
#  'Rp. 5,000,000 - Rp. 20,000,000' 'Kurang dari Rp. 500,000']

# %%
unique_penghasilan = data['Penghasilan Ibu'].unique()

# %%
print("Penghasilan yang ditemukan:", unique_penghasilan)
# Out:
# Penghasilan yang ditemukan: ['Tidak Berpenghasilan' 'Rp. 1,000,000 - Rp. 1,999,999'
#  'Rp. 2,000,000 - Rp. 4,999,999' 'Rp. 500,000 - Rp. 999,999'
#  'Kurang dari Rp. 500,000' 'Rp. 5,000,000 - Rp. 20,000,000']

# %%
PenghasilanAyah_map={"0":0,"Tidak Berpenghasilan":1, "Kurang dari Rp. 500,000":2, "Rp. 500,000 - Rp. 999,999":3, "Rp. 1,000,000 - Rp. 1,999,999":4, "Rp. 2,000,000 - Rp. 4,999,999":5, "Rp. 5,000,000 - Rp. 20,000,000":6}
data["Penghasilan Ayah"]=data["Penghasilan Ayah"].map(PenghasilanAyah_map)

# %%
data.head()
# Out:
#        Jenis Tinggal Alat Transportasi Penerima KPS   Pekerjaan Ayah  \
# 0  Bersama orang tua            Sepeda           Ya   Pedagang Kecil
# 1  Bersama orang tua            Sepeda        Tidak  Karyawan Swasta
# 2  Bersama orang tua      Sepeda motor        Tidak  Karyawan Swasta
# 3  Bersama orang tua      Sepeda motor        Tidak  Karyawan Swasta
# 4  Bersama orang tua      Sepeda motor        Tidak  Karyawan Swasta
#
#    Penghasilan Ayah    Pekerjaan Ibu                Penghasilan Ibu  \
# 0                 3    Tidak bekerja           Tidak Berpenghasilan
# 1                 4  Karyawan Swasta  Rp. 1,000,000 - Rp. 1,999,999
# 2                 5  Karyawan Swasta  Rp. 2,000,000 - Rp. 4,999,999
# 3                 5    Tidak bekerja           Tidak Berpenghasilan
# 4                 5    Tidak bekerja           Tidak Berpenghasilan
#
#   Penerima KIP Layak PIP (usulan dari sekolah) Kebutuhan Khusus
# 0           Ya                              Ya        Tidak ada
# ...

# %%
PenghasilanIbu_map={"0":0,"Tidak Berpenghasilan":1, "Kurang dari Rp. 500,000":2, "Rp. 500,000 - Rp. 999,999":3, "Rp. 1,000,000 - Rp. 1,999,999":4, "Rp. 2,000,000 - Rp. 4,999,999":5, "Rp. 5,000,000 - Rp. 20,000,000":6}
data["Penghasilan Ibu"]=data["Penghasilan Ibu"].map(PenghasilanIbu_map)

# %%
# Identifikasi kolom numerik
numerical_columns = ['Penghasilan Ayah', 'Penghasilan Ibu']  # Ganti dengan kolom numerik dalam dataset Anda

for column in numerical_columns:
    # Hitung Q1, Q3, dan IQR
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1

    # Tentukan batas bawah dan atas
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Filter outlier
    outliers = data[(data[column] < lower_bound) | (data[column] > upper_bound)]
    print(f"Kolom: {column}")
    print(f"Jumlah outlier: {len(outliers)}")
    print(outliers)
    print("\n")
# Out:
# Kolom: Penghasilan Ayah
# Jumlah outlier: 195
#           Jenis Tinggal            Alat Transportasi Penerima KPS  \
# 25    Bersama orang tua                   Jalan kaki        Tidak
# 39    Bersama orang tua                       Sepeda        Tidak
# 45    Bersama orang tua                 Sepeda motor        Tidak
# 70    Bersama orang tua                 Sepeda motor        Tidak
# 71    Bersama orang tua                   Jalan kaki        Tidak
# ...                 ...                          ...          ...
# 2395               Wali                   Jalan kaki        Tidak
# 2432  Bersama orang tua  Angkutan umum/bus/pete-pete        Tidak
# 2446  Bersama orang tua                   Jalan kaki        Tidak
# 2492  Bersama orang tua                 Sepeda motor        Tidak
# 2493  Bersama orang tua                   Jalan kaki        Tidak
#
#        Pekerjaan Ayah  Penghasilan Ayah           Pekerjaan Ibu  \
# ...

# %%
import numpy as np

# %%
data['Penghasilan Ayah'] = np.where(data['Penghasilan Ayah'] < lower_bound, lower_bound, data['Penghasilan Ayah'])
data['Penghasilan Ayah'] = np.where(data['Penghasilan Ayah'] > upper_bound, upper_bound, data['Penghasilan Ayah'])

# %%
# Periksa ulang outlier setelah menangani
outliers = data[(data['Penghasilan Ayah'] < lower_bound) | (data['Penghasilan Ayah'] > upper_bound)]
print(f"Jumlah outlier setelah penanganan: {len(outliers)}")
# Out:
# Jumlah outlier setelah penanganan: 0

# %%
outliers = data[(data['Penghasilan Ibu'] < lower_bound) | (data['Penghasilan Ibu'] > upper_bound)]
print(f"Jumlah outlier : {len(outliers)}")
# Out:
# Jumlah outlier : 0

# %%
# Menampilkan jenis pekerjaan Ayah
jenis_pekerjaan_ayah = data['Pekerjaan Ayah'].unique()
print("Jenis pekerjaan Ayah:")
print(jenis_pekerjaan_ayah)

# Menampilkan jenis pekerjaan Ibu
jenis_pekerjaan_ibu = data['Pekerjaan Ibu'].unique()
print("\nJenis pekerjaan Ibu:")
print(jenis_pekerjaan_ibu)
# Out:
# Jenis pekerjaan Ayah:
# ['Pedagang Kecil' 'Karyawan Swasta' 'Wiraswasta' 'PNS/TNI/Polri' 'Lainnya'
#  'Tidak bekerja' 'Wirausaha' 'Buruh' 'Sudah Meninggal' 'Tidak Diketahui'
#  'Pensiunan' 'Petani' 'Pedagang Besar' 'Tidak dapat diterapkan' 'Peternak']
#
# Jenis pekerjaan Ibu:
# ['Tidak bekerja' 'Karyawan Swasta' 'Wiraswasta' 'Buruh' 'Pedagang Kecil'
#  'Wirausaha' 'Lainnya' 'Sudah Meninggal' 'Petani' 'PNS/TNI/Polri'
#  'Pedagang Besar' 'Tidak dapat diterapkan' 'Peternak' 'Pensiunan']

# %%
# Menampilkan jenis penerima KPS
print("Jenis nilai unik untuk Penerima KPS:")
print(data['Penerima KPS'].unique())
# Out:
# Jenis nilai unik untuk Penerima KPS:
# ['Ya' 'Tidak']

# %%
# Menampilkan jenis penerima KIP
print("\nJenis nilai unik untuk Penerima KIP:")
print(data['Penerima KIP'].unique())
# Out:
# Jenis nilai unik untuk Penerima KIP:
# ['Ya' 'Tidak']

# %%
# Menampilkan jenis tinggal
print("\nJenis nilai unik untuk Jenis Tinggal:")
print(data['Jenis Tinggal'].unique())
# Out:
# Jenis nilai unik untuk Jenis Tinggal:
# ['Bersama orang tua' 'Wali' 'Kost' 'Pesantren' 'Lainnya' 'Asrama'
#  'Panti asuhan']

# %%
# Menampilkan jenis kebutuhan khusus
print("\nJenis nilai unik untuk Kebutuhan Khusus:")
print(data['Kebutuhan Khusus'].unique())
# Out:
# Jenis nilai unik untuk Kebutuhan Khusus:
# ['Tidak ada' 'K - Kesulitan Belajar' 'C - Tuna grahita ringan'
#  'C1 - Tuna grahita sedang' 'C1,K' 'B,K' 'B - Tuna rungu']

# %%
# Label pekerjaan Ayah dan Ibu
label_pekerjaan_ayah_ibu = {
    'Pedagang Kecil': 1,
    'Karyawan Swasta': 2,
    'Wiraswasta': 3,
    'PNS/TNI/Polri': 4,
    'Tidak bekerja': 5,
    'Wirausaha': 6,
    'Buruh': 7,
    'Sudah Meninggal': 8,
    'Tidak Diketahui': 9,
    'Pensiunan': 10,
    'Petani': 11,
    'Pedagang Besar': 12,
    'Tidak dapat diterapkan': 13,
    'Peternak': 14,
    'Lainnya':0
}
# Mapping langsung ke kolom Pekerjaan Ayah dan Pekerjaan Ibu
data['Pekerjaan Ayah'] = data['Pekerjaan Ayah'].map({'Lainnya':0, 'Pedagang Kecil':1, 'Karyawan Swasta':2, 'Wiraswasta':3, 'PNS/TNI/Polri':4, 'Tidak bekerja':5, 'Wirausaha':6,
                                                     'Buruh':7, 'Sudah Meninggal':8, 'Tidak Diketahui':9, 'Pensiunan':10, 'Petani':11, 'Pedagang Besar':12, 'Tidak dapat diterapkan':13,
                                                     'Peternak':14})
data['Pekerjaan Ibu'] = data['Pekerjaan Ibu'].map({'Lainnya':0, 'Pedagang Kecil':1, 'Karyawan Swasta':2, 'Wiraswasta':3, 'PNS/TNI/Polri':4, 'Tidak bekerja':5, 'Wirausaha':6,
                                                     'Buruh':7, 'Sudah Meninggal':8, 'Tidak Diketahui':9, 'Pensiunan':10, 'Petani':11, 'Pedagang Besar':12, 'Tidak dapat diterapkan':13,
                                                     'Peternak':14})

# %%
data.head()
# Out:
#        Jenis Tinggal Alat Transportasi Penerima KPS  Pekerjaan Ayah  \
# 0  Bersama orang tua            Sepeda           Ya               1
# 1  Bersama orang tua            Sepeda        Tidak               2
# 2  Bersama orang tua      Sepeda motor        Tidak               2
# 3  Bersama orang tua      Sepeda motor        Tidak               2
# 4  Bersama orang tua      Sepeda motor        Tidak               2
#
#    Penghasilan Ayah  Pekerjaan Ibu  Penghasilan Ibu Penerima KIP  \
# 0               3.0              5                1           Ya
# 1               4.0              2                4        Tidak
# 2               5.0              2                5        Tidak
# 3               5.0              5                1        Tidak
# 4               5.0              5                1        Tidak
#
#   Layak PIP (usulan dari sekolah) Kebutuhan Khusus
# 0                              Ya        Tidak ada
# 1                           Tidak        Tidak ada
# ...

# %%
# Label penerima KPS
data['Penerima KPS'] = data['Penerima KPS'].map({'Ya': 1, 'Tidak': 0})

# Label penerima KIP
data['Penerima KIP'] = data['Penerima KIP'].map({'Ya': 1, 'Tidak': 0})

# %%
label_tinggal = {
    'Bersama orang tua': 1,
    'Wali': 2,
    'Kost': 3,
    'Pesantren': 4,
    'Asrama': 5,
    'Panti asuhan': 6,
    'Lainnya': 0
}

data['Jenis Tinggal'] = data['Jenis Tinggal'].map({'Bersama orang tua':1, 'Wali':2, 'Kost':3, 'Pesantren':4, 'Asrama':5, 'Panti asuhan':6, 'Lainnya':0})

# %%
label_kebutuhan_khusus = {
    'Tidak ada': 0,
    'K - Kesulitan Belajar': 1,
    'C - Tuna grahita ringan': 2,
    'C1 - Tuna grahita sedang': 3,
    'C1,K': 4,
    'B,K': 5,
    'B - Tuna rungu': 6
}

data['Kebutuhan Khusus'] = data['Kebutuhan Khusus'].map({'Tidak ada':0, 'K - Kesulitan Belajar':1, 'C - Tuna grahita ringan':2, 'C1 - Tuna grahita sedang':3, 'C1,K':4, 'B,K':5, 'B - Tuna rungu':6})

# %%
data.head()
# Out:
#    Jenis Tinggal Alat Transportasi  Penerima KPS  Pekerjaan Ayah  \
# 0              1            Sepeda             1               1
# 1              1            Sepeda             0               2
# 2              1      Sepeda motor             0               2
# 3              1      Sepeda motor             0               2
# 4              1      Sepeda motor             0               2
#
#    Penghasilan Ayah  Pekerjaan Ibu  Penghasilan Ibu  Penerima KIP  \
# 0               3.0              5                1             1
# 1               4.0              2                4             0
# 2               5.0              2                5             0
# 3               5.0              5                1             0
# 4               5.0              5                1             0
#
#   Layak PIP (usulan dari sekolah)  Kebutuhan Khusus
# 0                              Ya                 0
# 1                           Tidak                 0
# ...

# %%
# Menampilkan jenis kebutuhan khusus
print("\nJenis nilai unik untuk Alat Transportasi:")
print(data['Alat Transportasi'].unique())
# Out:
# Jenis nilai unik untuk Alat Transportasi:
# ['Sepeda' 'Sepeda motor' 'Jalan kaki' 'Mobil pribadi'
#  'Mobil/bus antar jemput' 'Andong/bendi/sado/dokar/delman/becak' 'Ojek'
#  'Angkutan umum/bus/pete-pete' 'Lainnya']

# %%
label_alat_transportasi = {
    'Sepeda': 1,
    'Sepeda motor': 2,
    'Jalan kaki': 3,
    'Mobil pribadi': 4,
    'Mobil/bus antar jemput': 5,
    'Andong/bendi/sado/dokar/delman/becak': 6,
    'Ojek': 7,
    'Angkutan umum/bus/pete-pete': 8,
    'Lainnya': 0
}

data['Alat Transportasi'] = data['Alat Transportasi'].map({'Lainnya':0, 'Sepeda':1, 'Sepeda motor':2, 'Jalan kaki':3, 'Mobil pribadi':4, 'Mobil/bus antar jemput':5, 'Andong/bendi/sado/dokar/delman/becak':6, 'Ojek':7, 'Angkutan umum/bus/pete-pete':8})

# %%
data.head()
# Out:
#    Jenis Tinggal  Alat Transportasi  Penerima KPS  Pekerjaan Ayah  \
# 0              1                  1             1               1
# 1              1                  1             0               2
# 2              1                  2             0               2
# 3              1                  2             0               2
# 4              1                  2             0               2
#
#    Penghasilan Ayah  Pekerjaan Ibu  Penghasilan Ibu  Penerima KIP  \
# 0               3.0              5                1             1
# 1               4.0              2                4             0
# 2               5.0              2                5             0
# 3               5.0              5                1             0
# 4               5.0              5                1             0
#
#   Layak PIP (usulan dari sekolah)  Kebutuhan Khusus
# 0                              Ya                 0
# 1                           Tidak                 0
# ...

# %%
# Menampilkan jenis kelayakan penerimaan PIP
print("\nJenis nilai unik untuk Layak PIP:")
print(data['Layak PIP (usulan dari sekolah)'].unique())
# Out:
# Jenis nilai unik untuk Layak PIP:
# ['Ya' 'Tidak']

# %%
# Label penerima KPS
data['Layak PIP (usulan dari sekolah)'] = data['Layak PIP (usulan dari sekolah)'].map({'Ya': 1, 'Tidak': 0})

# %%
data.head()
# Out:
#    Jenis Tinggal  Alat Transportasi  Penerima KPS  Pekerjaan Ayah  \
# 0              1                  1             1               1
# 1              1                  1             0               2
# 2              1                  2             0               2
# 3              1                  2             0               2
# 4              1                  2             0               2
#
#    Penghasilan Ayah  Pekerjaan Ibu  Penghasilan Ibu  Penerima KIP  \
# 0               3.0              5                1             1
# 1               4.0              2                4             0
# 2               5.0              2                5             0
# 3               5.0              5                1             0
# 4               5.0              5                1             0
#
#    Layak PIP (usulan dari sekolah)  Kebutuhan Khusus
# 0                                1                 0
# 1                                0                 0
# ...

# %%
data_setelah_diolah = pd.DataFrame(data)

# %%
data_setelah_diolah
# Out:
#       Jenis Tinggal  Alat Transportasi  Penerima KPS  Pekerjaan Ayah  \
# 0                 1                  1             1               1
# 1                 1                  1             0               2
# 2                 1                  2             0               2
# 3                 1                  2             0               2
# 4                 1                  2             0               2
# ...             ...                ...           ...             ...
# 2493              1                  3             0               7
# 2494              1                  2             0               2
# 2495              1                  5             0               2
# 2496              1                  1             0               2
# 2497              1                  1             0               2
#
#       Penghasilan Ayah  Pekerjaan Ibu  Penghasilan Ibu  Penerima KIP  \
# ...

# %%
data_setelah_diolah.to_csv('dataset-siswasmkn6-setelah-diolah.csv', index=False)

# %%
data['Layak PIP (usulan dari sekolah)'].value_counts().plot(kind='bar')
data['Layak PIP (usulan dari sekolah)'].value_counts()
# Out:
# Layak PIP (usulan dari sekolah)
# 0    1574
# 1     924
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
xdata = data.drop('Layak PIP (usulan dari sekolah)', axis=1)
ydata = data['Layak PIP (usulan dari sekolah)']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(xdata, ydata, test_size=0.3, random_state=1)

# %%
nb_clf = GaussianNB()
nb_clf.fit(xtrain, ytrain)
# Out:
# GaussianNB()

# %%
y_pred = nb_clf.predict(xtest)

# %%
accuracy = metrics.accuracy_score(ytest, y_pred)
print("Akurasi:", accuracy * 100, "%")
# Out:
# Akurasi: 74.4 %

# %%
xtrain, xtest, ytrain, ytest = train_test_split(xdata, ydata, test_size=0.2, random_state=42)

# %%
nb_clf = GaussianNB()
nb_clf.fit(xtrain, ytrain)
# Out:
# GaussianNB()

# %%
y_pred = nb_clf.predict(xtest)

# %%
accuracy = metrics.accuracy_score(ytest, y_pred)
print("Akurasi:", accuracy * 100, "%")
# Out:
# Akurasi: 75.0 %

# %%
xtrain, xtest, ytrain, ytest = train_test_split(xdata, ydata, test_size=0.4, random_state=0)

# %%
nb_clf = GaussianNB()
nb_clf.fit(xtrain, ytrain)
# Out:
# GaussianNB()

# %%
y_pred = nb_clf.predict(xtest)

# %%
accuracy = metrics.accuracy_score(ytest, y_pred)
print("Akurasi:", accuracy * 100, "%")
# Out:
# Akurasi: 75.5 %

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
xtrain, xtest, ytrain, ytest = train_test_split(xdata, ydata, test_size=0.3, random_state=1)

# %%
clf_dt = DecisionTreeClassifier()
clf_dt.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
ypred_dt = clf_dt.predict(xtest)

# %%
accuracy_dt = metrics.accuracy_score(ytest, ypred_dt) * 100
print("Akurasi Decision Tree:", accuracy_dt)
# Out:
# Akurasi Decision Tree: 73.06666666666666

# %% [markdown]
# Tahap Evaluasi Model Klasifikasi

# %%
xtrain, xtest, ytrain, ytest = train_test_split(xdata, ydata, test_size=0.4, random_state=0)

# %%
NB = GaussianNB().fit(xtrain, ytrain)

# %%
NBpred = NB.predict(xtest)

# %%
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, roc_curve

# %%
print(classification_report(ytest,NBpred))
print("Akurasi Model Naive Bayes: ", accuracy_score(ytest, NBpred) * 100)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.98      0.83       626
#            1       0.93      0.37      0.53       374
#
#     accuracy                           0.76      1000
#    macro avg       0.83      0.68      0.68      1000
# weighted avg       0.80      0.76      0.72      1000
#
# Akurasi Model Naive Bayes:  75.5

# %%
NB_roc_auc = roc_auc_score(ytest, NB.predict(xtest))
NB_fpr, nb_tpr, nb_thresholds = roc_curve(ytest, NB.predict_proba(xtest)[:,1])
plt.figure()
plt.plot(NB_fpr, nb_tpr, label='NB (AUC = %0.2f)' % NB_roc_auc)
plt.plot([0, 1],[0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
